# %%
print("Some")
# Out:
# Some

# %%
s={
    (1,2,4):"some",
    "another":[4,6,8],
    "group":[9,11,56]
   }

print(len(s))

for char in s:
    print(char,s[char])
# Out:
# 3
# (1, 2, 4) some
# another [4, 6, 8]
# group [9, 11, 56]

# %%
a1=[0,0,1,0,1,2]
a2=[0,1,1,0,1,2]

print(a1 == a2)
# Out:
# False

# %%
print((1,1,3)==(1,1,2))
# Out:
# False

# %%
print(tuple([1,2,1,5,6,2,1,1]))
# Out:
# (1, 2, 1, 5, 6, 2, 1, 1)
